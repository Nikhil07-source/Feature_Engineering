# %% [markdown]
# #__Feature Engineering__
#
# ## __1. Introduction__
# It refers to the process of selecting, modifying, or creating new features (variables) from the raw data to improve the performance of machine learning models.
# - It involves transforming the data into a more suitable format, making it easier for models to learn patterns and make accurate predictions.
# - It is a critical step in the data preprocessing pipeline and plays a key role in the success of machine learning projects.

# %% [markdown]
# ## __2. Feature Engineering Methods__
#
# They introduce the concept of creating new features through mathematical operations, transformations, or combining existing variables.
#
# __Note:__ The __Data Wrangling__ lesson extensively addresses various feature engineering methods, including outlier handling, imputation, and data cleaning. Any aspects not covered in that lesson but deemed essential for feature engineering are comprehensively discussed here.
#
# ![](https://serokell.io/files/nl/nl5ojqwx.Feature__Engineering_pic4.png)

# %%
import pandas as pd #importing pandas library as pd
import numpy as np  #import numpy library as np

df = pd.read_csv('HousePrices.csv') #importing a csv file using pandas
df['total_rooms'] = df['bedrooms']+df['bathrooms'] #creating a new column named 'total_rooms' by combining 'bedrooms' & 'bathrooms' columns.
df #printing Dataframe
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country  total_rooms
# 0     Shoreline  WA 98133     USA         4.50
# 1       Seattle  WA 98119     USA         7.50
# 2          Kent  WA 98042     USA         5.00
# 3      Bellevue  WA 98008     USA         5.25
# 4       Redmond  WA 98052     USA         6.50
# ...         ...       ...     ...          ...
# 4595    Seattle  WA 98133     USA         4.75
# 4596   Bellevue  WA 98007     USA         5.50
# 4597     Renton  WA 98059     USA         5.50
# 4598    Seattle  WA 98178     USA         6.00
# 4599  Covington  WA 98042     USA         5.50
#
# [4600 rows x 19 columns]

# %% [markdown]
# ## __3. Transforming Variables__
# Transforming variables is a crucial aspect of feature engineering that involves modifying the scale, distribution, or nature of variables to meet certain assumptions or to make them more suitable for analysis or modeling.
# - Here are common techniques for transforming variables:.
# 1. Log Transformation
# 2. Square root Transformation
# 3. Box - Cox Transformation

# %% [markdown]
# ### __3.1 Log Transformation__
#
# Log transformation is useful for handling skewed data or reducing the impact of outliers. It applies the natural logarithm to the variable values.

# %%
df['log_price'] = np.log(df['price'])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country  total_rooms  log_price
# 0     Shoreline  WA 98133     USA         4.50  12.653958
# 1       Seattle  WA 98119     USA         7.50  14.684290
# 2          Kent  WA 98042     USA         5.00  12.742566
# 3      Bellevue  WA 98008     USA         5.25  12.948010
# 4       Redmond  WA 98052     USA         6.50  13.217674
# ...         ...       ...     ...          ...        ...
# 4595    Seattle  WA 98133     USA         4.75  12.638396
# 4596   Bellevue  WA 98007     USA         5.50  13.188775
# 4597     Renton  WA 98059     USA         5.50  12.940612
# 4598    Seattle  WA 98178     USA         6.00  12.222930
# 4599  Covington  WA 98042     USA         5.50  12.304106
#
# [4600 rows x 20 columns]

# %% [markdown]
# ### __3.2 Square Root Transformation__
# Similar to log transformation, square root transformation is effective for stabilizing variance and handling skewed distributions.

# %%
df['Squareroot_price'] = np.sqrt(df['price'])
df[['Squareroot_price','price']]
# Out:
#       Squareroot_price         price
# 0           559.464029  3.130000e+05
# 1          1544.020725  2.384000e+06
# 2           584.807661  3.420000e+05
# 3           648.074070  4.200000e+05
# 4           741.619849  5.500000e+05
# ...                ...           ...
# 4595        555.127613  3.081667e+05
# 4596        730.981076  5.343333e+05
# 4597        645.681165  4.169042e+05
# 4598        450.998891  2.034000e+05
# 4599        469.680743  2.206000e+05
#
# [4600 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
df['price'].plot.density(color='green')
plt.title('Density Plot for Price')
plt.show()

# %%
import matplotlib.pyplot as plt
df['Squareroot_price'].plot.density(color='red')
plt.title('Density Plot for Squarefoot Price')
plt.show()

# %% [markdown]
# ### __3.3 Box-Cox Transformation__
#
# Box-cox transformation is a family of power transformations that includes both log and square root transformations.
# - It can handle a broader range of data distributions.

# %%
from scipy.stats import boxcox
#Applying Box-Cox transformation to 'sqft_living' variable
boxcox_result = boxcox(df['sqft_living'] + 1)
df['boxcox_sqft_living'] = boxcox_result[0]
df[['sqft_living','boxcox_sqft_living']]
# Out:
#       sqft_living  boxcox_sqft_living
# 0            1340            8.255097
# 1            3650            9.588124
# 2            1930            8.734654
# 3            2000            8.781836
# 4            1940            8.741494
# ...           ...                 ...
# 4595         1510            8.411362
# 4596         1460            8.367235
# 4597         3010            9.327754
# 4598         2090            8.840216
# 4599         1490            8.393882
#
# [4600 rows x 2 columns]

# %%
df['sqft_living'].plot.density(color='orange')
plt.title('Density plot for SquareFoot Living')
plt.show()

# %%
df['boxcox_sqft_living'].plot.density(color='blue')
plt.title('Density plot for Box-Cox SquareFoot Living')
plt.show()

# %% [markdown]
# ## __4. Feature Scaling__
# Feature scaling is a technique used in machine learning and data preprocessing to standardize or normalize the range of independent variables or features of a dataset.
# - Min-Max scaling transforms the data to the specific range, typically between 0 and 1, preserving the relative differences between values. This normalization techniques is ideal with datasets woth known bounds, ensuring that all values are rescaled propotionally to fit within the specified range.
# - Standard Scaling is preferable for normally distribution data to maintain mean-centeredness and consistent standards deviations (-1 : +1).
#
# ![label_encoding_&_one_hot_encoding](https://miro.medium.com/v2/resize:fit:1400/0*T5jaa2othYfXZX9W.)

# %% [markdown]
# ## __5. Label Encoding__ (0/1/2/3 ...etc)
#
# Label encoding is a technique used to convert categorical labels into a numeric format, making it suitable for machine learning algorithms that require numerical input.
# - In label encoding, each unique category is assigned an integer value.
# - This is particularly useful when dealing with ordinal categorical data, where the order of categories matters.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df_test = pd.DataFrame({'Size':['Small','Medium','Large','ExtraLarge','Small','Small','Medium','ExtraLarge','Medium']})
print('Data before Label Encoding:\n', df_test)

label_encoding = LabelEncoder()
df_test['LE'] = label_encoding.fit_transform(df_test['Size'])
print('\n\nData after Label Encoding:\n', df_test)
# Out:
# Data before Label Encoding:
#           Size
# 0       Small
# 1      Medium
# 2       Large
# 3  ExtraLarge
# 4       Small
# 5       Small
# 6      Medium
# 7  ExtraLarge
# 8      Medium
#
#
# Data after Label Encoding:
#           Size  LE
# 0       Small   3
# 1      Medium   2
# 2       Large   1
# 3  ExtraLarge   0
# 4       Small   3
# 5       Small   3
# 6      Medium   2
# 7  ExtraLarge   0
# 8      Medium   2

# %%
#Using Label Encoding in above HousingPrice.csv

le = LabelEncoder()
df['city_encoder'] = le.fit_transform(df['city'])
df[['city','city_encoder']]
# Out:
#            city  city_encoder
# 0     Shoreline            36
# 1       Seattle            35
# 2          Kent            18
# 3      Bellevue             3
# 4       Redmond            31
# ...         ...           ...
# 4595    Seattle            35
# 4596   Bellevue             3
# 4597     Renton            32
# 4598    Seattle            35
# 4599  Covington             9
#
# [4600 rows x 2 columns]

# %% [markdown]
# ## __6. One-Hot Encoding__ (True/False)
#
# One-hot encoding is a technique used to represent categorical variables as binary vectors.
# - It is particularly useful when dealing with nominal categorical data, where there is no inherent order among categories.
# - In one-hot encoding, each unique category is transformed into a binary column, and only one column in each set of binary columns is _hot_ (or 1) to indicate the presence of that category.

# %%
#Before One Hot Encoding
color_df = pd.DataFrame({'Color': ['Red','Blue','Green','Pink','Yellow','Orange','Blue','Red','Green','Green','Blue','Orange']})
print('Data before One Hot Encoding:\n', color_df)

#After One Hot Encoding
OHE = pd.get_dummies(color_df, columns=['Color'])
print('\n\nData after One Hot Encoding:\n',OHE)
# Out:
# Data before One Hot Encoding:
#       Color
# 0      Red
# 1     Blue
# 2    Green
# 3     Pink
# 4   Yellow
# 5   Orange
# 6     Blue
# 7      Red
# 8    Green
# 9    Green
# 10    Blue
# 11  Orange
#
#
# Data after One Hot Encoding:
#      Color_Blue  Color_Green  Color_Orange  Color_Pink  Color_Red  Color_Yellow
# 0        False        False         False       False       True         False
# 1         True        False         False       False      False         False
# 2        False         True         False       False      False         False
# 3        False        False         False        True      False         False
# 4        False        False         False       False      False          True
# 5        False        False          True       False      False         False
# 6         True        False         False       False      False         False
# 7        False        False         False       False       True         False
# 8        False         True         False       False      False         False
# 9        False         True         False       False      False         False
# 10        True        False         False       False      False         False
# 11       False        False          True       False      False         False

# %%
#Demonstrating One Hot Encoding in csv Dataframe
#One Hot Encoding on View Column
view_encoded = pd.get_dummies(df, columns=['view'])
print(view_encoded)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  condition  sqft_above  ...  total_rooms  \
# 0         7912     1.5           0          3        1340  ...         4.50
# 1         9050     2.0           0          5        3370  ...         7.50
# 2        11947     1.0           0          4        1930  ...         5.00
# 3         8030     1.0           0          4        1000  ...         5.25
# 4        10500     1.0           0          4        1140  ...         6.50
# ...        ...     ...         ...        ...         ...  ...          ...
# 4595      6360     1.0           0          4        1510  ...         4.75
# 4596      7573     2.0           0          3        1460  ...         5.50
# 4597      7014     2.0           0          3        3010  ...         5.50
# 4598      6630     1.0           0          3        1070  ...         6.00
# 4599      8102     2.0           0          4        1490  ...         5.50
#
#       log_price  Squareroot_price boxcox_sqft_living city_encoder view_0  \
# 0     12.653958        559.464029           8.255097           36   True
# 1     14.684290       1544.020725           9.588124           35  False
# 2     12.742566        584.807661           8.734654           18   True
# 3     12.948010        648.074070           8.781836            3   True
# 4     13.217674        741.619849           8.741494           31   True
# ...         ...               ...                ...          ...    ...
# 4595  12.638396        555.127613           8.411362           35   True
# 4596  13.188775        730.981076           8.367235            3   True
# 4597  12.940612        645.681165           9.327754           32   True
# 4598  12.222930        450.998891           8.840216           35   True
# 4599  12.304106        469.680743           8.393882            9   True
#
#      view_1  view_2  view_3  view_4
# 0     False   False   False   False
# 1     False   False   False    True
# 2     False   False   False   False
# 3     False   False   False   False
# 4     False   False   False   False
# ...     ...     ...     ...     ...
# 4595  False   False   False   False
# 4596  False   False   False   False
# 4597  False   False   False   False
# 4598  False   False   False   False
# 4599  False   False   False   False
#
# [4600 rows x 27 columns]

# %% [markdown]
# ## __7. Hashing__
#
# It is a technique used to convert input data (of variable length) into a fixed-length string of characters, typically a hash code.
# - The hash function takes an input (or message) and returns a fixed-size string of characters, which is typically a hexadecimal number.
# - It is commonly used for indexing data structures, checking data integrity, and hashing passwords.
#
#
# ![image.png](https://images.javatpoint.com/ds/images/hash-table.png)

# %%
data = "Hello, Hashing!"
hash_value = hash(data)
print('Orignal String:', data,'\n Hashed Valued',hash_value)
# Out:
# Orignal String: Hello, Hashing!
#  Hashed Valued -997467322235589656

# %%
#Converting 'street' value to hash value and going to save that value in new column name 'street_hash'
df['street_hash'] = df['street'].apply(hash) #Applying hash to street
print(df[['street','street_hash']])
# Out:
#                         street          street_hash
# 0         18810 Densmore Ave N -3224616366330650817
# 1              709 W Blaine St  1247358197422136891
# 2     26206-26214 143rd Ave SE  1458011763434864008
# 3              857 170th Pl NE  8245335035365044572
# 4            9105 170th Ave NE -8663721688323038452
# ...                        ...                  ...
# 4595            501 N 143rd St -8060503085593713971
# 4596          14855 SE 10th Pl -3148063271279187023
# 4597          759 Ilwaco Pl NE  5484841823332770075
# 4598         5148 S Creston St -4889229802904677428
# 4599         18717 SE 258th St -5788516639000534243
#
# [4600 rows x 2 columns]

# %% [markdown]
# ## __8. Grouping Operations__
#
# Grouping operations involve splitting a dataset into groups based on some criteria, applying a function to each group independently, and then combining the results.
# - This is a crucial step in data analysis and manipulation, allowing for insights into the data at a more granular level.
# - Grouping operations are commonly used in combination with aggregate functions to summarize data within each group.

# %%
import pandas as pd

df3 = pd.DataFrame({'Category':['A','B','C','C','C','A','B','B'],
                    'Value':[10,20,30,40,50,60,70,80]})
#grouping by 'Category' and calculating total revenue for each category
grouped_data = df3.groupby('Category')['Value'].sum() #we cal also write - mean, median ,mode, std, var......etc
grouped_data
# Out:
# Category
# A     70
# B    170
# C    120
# Name: Value, dtype: int64

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  ...  \
# 0         7912     1.5           0     0          3  ...
# 1         9050     2.0           0     4          5  ...
# 2        11947     1.0           0     0          4  ...
# 3         8030     1.0           0     0          4  ...
# 4        10500     1.0           0     0          4  ...
# ...        ...     ...         ...   ...        ...  ...
# 4595      6360     1.0           0     0          4  ...
# 4596      7573     2.0           0     0          3  ...
# 4597      7014     2.0           0     0          3  ...
# 4598      6630     1.0           0     0          3  ...
# 4599      8102     2.0           0     0          4  ...
#
#                         street       city  statezip  country total_rooms  \
# 0         18810 Densmore Ave N  Shoreline  WA 98133      USA        4.50
# 1              709 W Blaine St    Seattle  WA 98119      USA        7.50
# 2     26206-26214 143rd Ave SE       Kent  WA 98042      USA        5.00
# 3              857 170th Pl NE   Bellevue  WA 98008      USA        5.25
# 4            9105 170th Ave NE    Redmond  WA 98052      USA        6.50
# ...                        ...        ...       ...      ...         ...
# 4595            501 N 143rd St    Seattle  WA 98133      USA        4.75
# 4596          14855 SE 10th Pl   Bellevue  WA 98007      USA        5.50
# 4597          759 Ilwaco Pl NE     Renton  WA 98059      USA        5.50
# 4598         5148 S Creston St    Seattle  WA 98178      USA        6.00
# 4599         18717 SE 258th St  Covington  WA 98042      USA        5.50
#
#       log_price Squareroot_price boxcox_sqft_living  city_encoder  \
# 0     12.653958       559.464029           8.255097            36
# 1     14.684290      1544.020725           9.588124            35
# 2     12.742566       584.807661           8.734654            18
# 3     12.948010       648.074070           8.781836             3
# 4     13.217674       741.619849           8.741494            31
# ...         ...              ...                ...           ...
# 4595  12.638396       555.127613           8.411362            35
# 4596  13.188775       730.981076           8.367235             3
# 4597  12.940612       645.681165           9.327754            32
# 4598  12.222930       450.998891           8.840216            35
# 4599  12.304106       469.680743           8.393882             9
#
#               street_hash
# 0    -3224616366330650817
# 1     1247358197422136891
# 2     1458011763434864008
# 3     8245335035365044572
# 4    -8663721688323038452
# ...                   ...
# 4595 -8060503085593713971
# 4596 -3148063271279187023
# 4597  5484841823332770075
# 4598 -4889229802904677428
# 4599 -5788516639000534243
#
# [4600 rows x 24 columns]

# %%
#Demonstrating grouping by in csv file in 'cities' wise and caluclating mean of 'price' column.
city_grouped = df.groupby('city')['price'].mean().sort_values(ascending=False)
city_grouped
# Out:
# city
# Medina                 2.046559e+06
# Clyde Hill             1.321945e+06
# Yarrow Point           1.194838e+06
# Mercer Island          1.123818e+06
# Bellevue               8.471807e+05
# Beaux Arts Village     7.450000e+05
# Fall City              6.926818e+05
# Sammamish              6.869176e+05
# Redmond                6.676495e+05
# Newcastle              6.660467e+05
# Kirkland               6.515836e+05
# Woodinville            6.095650e+05
# Issaquah               5.961637e+05
# Seattle                5.798375e+05
# Preston                5.624500e+05
# Snoqualmie             5.363053e+05
# Snoqualmie Pass        5.250000e+05
# Ravensdale             5.140714e+05
# Carnation              5.087520e+05
# Normandy Park          5.067931e+05
# Bothell                4.814419e+05
# Vashon                 4.725569e+05
# Lake Forest Park       4.484750e+05
# Kenmore                4.474940e+05
# Kent                   4.394924e+05
# Inglewood-Finn Hill    4.250000e+05
# Shoreline              4.203924e+05
# Duvall                 4.039941e+05
# North Bend             3.995657e+05
# Renton                 3.770410e+05
# Burien                 3.489472e+05
# Black Diamond          3.396056e+05
# Maple Valley           3.364749e+05
# Tukwila                3.082901e+05
# Enumclaw               3.076146e+05
# Des Moines             3.049925e+05
# Auburn                 2.993404e+05
# Covington              2.962304e+05
# Federal Way            2.898877e+05
# Milton                 2.850000e+05
# SeaTac                 2.452906e+05
# Skykomish              2.330000e+05
# Pacific                2.252333e+05
# Algona                 2.072880e+05
# Name: price, dtype: float64
